# %% [markdown]
# ## **Open Payments 2020 General Payments Data : Hospital Information for the Hospital Table**

# %%
# packages to import
import numpy as np
import pandas as pd

# %% [markdown]
# The Open Payments data full csv file with 91 columns and millions of rows:
# * 2020 (3.7GB) https://download.cms.gov/openpayments/PGYR20_P012023/OP_DTL_GNRL_PGYR2020_P01202023.csv

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# My Team3Folder was in my top level of my Google drive. If yours isn't, then you just need to modify it to add the Folder hierarchy
# %cd /content/gdrive/MyDrive/Team3Folder/Data/Raw
# Out:
# /content/gdrive/MyDrive/Team3Folder/Data/Raw

# %%
# Read in columns needed for our data frame
df=pd.read_csv("OP_DTL_GNRL_PGYR2020_P01202023.csv", usecols=['Covered_Recipient_Type',
                  'Teaching_Hospital_CCN',
                  'Teaching_Hospital_ID',
                  'Teaching_Hospital_Name',
                  'Recipient_City',
                  'Recipient_State',
                  'Recipient_Zip_Code',
                  'Recipient_Country'])
df.shape
# Out:
# <ipython-input-4-2d0fa72e6589>:2: DtypeWarning: Columns (4,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("OP_DTL_GNRL_PGYR2020_P01202023.csv", usecols=['Covered_Recipient_Type',
# (5823162, 8)

# %%
# Retrieve the data for Hospitals only
df_hospitals=df[df["Covered_Recipient_Type"]!="Covered Recipient Physician"]
df_hospitals.shape
# Out:
# (32406, 8)

# %%
# Remove the duplicate rows if the Hosptials have the same identifying information of Teaching_Hospital_Id, Teaching_Hosptial_CCN and Teaching_Hospital_Name
df_unique_hospitals=df_hospitals.drop_duplicates( subset=['Teaching_Hospital_CCN','Teaching_Hospital_ID', 'Teaching_Hospital_Name'],keep=False, inplace=False)
print(df_unique_hospitals.shape)
df_unique_hospitals.head(10)
# Out:
# (447, 8)
#                     Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 1757   Covered Recipient Teaching Hospital               430016.0
# 1758   Covered Recipient Teaching Hospital               360055.0
# 1760   Covered Recipient Teaching Hospital               240063.0
# 1761   Covered Recipient Teaching Hospital               493301.0
# 2517   Covered Recipient Teaching Hospital               110006.0
# 2522   Covered Recipient Teaching Hospital               110087.0
# 2525   Covered Recipient Teaching Hospital               360020.0
# 7706   Covered Recipient Teaching Hospital               454076.0
# 8899   Covered Recipient Teaching Hospital               140010.0
# 10234  Covered Recipient Teaching Hospital               453302.0
#
#        Teaching_Hospital_ID              Teaching_Hospital_Name  \
# 1757                 9287.0                      Avera McKennan
# 1758                 9736.0          Trumbull Memorial Hospital
# 1760                 9226.0      Healtheast St Josephs Hospital
# 1761                 9371.0  Childrens Hospital of the Kings Da
# 2517                 9426.0     ST MARYS HEALTH CARE SYSTEM INC
# 2522                 9442.0        GWINNETT HOSPITAL SYSTEM INC
# 2525                 9032.0                 SUMMA HEALTH SYSTEM
# 7706                 9713.0        Harris Co Psychiatric Center
# 8899                 9083.0  NorthShore University HealthSystem
# 10234                9672.0  Childrens Medical Center of Dallas
#
#       Recipient_City Recipient_State Recipient_Zip_Code Recipient_Country
# 1757     Sioux Falls              SD              57117     United States
# 1758          Warran              OH              44483     United States
# 1760       Rochester              MN              55102     United States
# 1761         Norfolk              VA              23507     United States
# 2517          ATHENS              GA              30606     United States
# 2522   LAWRENCEVILLE              GA              30046     United States
# 2525           AKRON              OH              44308     United States
# 7706         Houston              TX              77225     United States
# 8899        Evanston              IL         60201-1613     United States
# 10234         Dallas              TX              75235     United States

# %%
df_unique_hospitals.columns
# Out:
# Index(['Covered_Recipient_Type', 'Teaching_Hospital_CCN',
#        'Teaching_Hospital_ID', 'Teaching_Hospital_Name', 'Recipient_City',
#        'Recipient_State', 'Recipient_Zip_Code', 'Recipient_Country'],
#       dtype='object')

# %%
#Makes sense to  rename the rest of the columns to simpler names
dict={
    "Teaching_Hospital_ID":"ID",
    "Teaching_Hospital_CCN":"CCN",
    "Teaching_Hospital_Name":"Hospital_Name",
    "Recipient_City":"City",
    "Recipient_State":"State",
    "Recipient_Zip_Code":"ZipCode",
    "Recipient_Country":"Country",
    "Covered_Recipient_Type":"Type"}
df_unique_hospitals.rename(columns=dict,inplace=True)
# Out:
# <ipython-input-8-8566acb12641>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unique_hospitals.rename(columns=dict,inplace=True)

# %%
#Now that we have reduced the size, Lets look at the columns
df_unique_hospitals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 1757 to 5822337
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           447 non-null    object
#  1   CCN            447 non-null    float64
#  2   ID             447 non-null    float64
#  3   Hospital_Name  447 non-null    object
#  4   City           447 non-null    object
#  5   State          447 non-null    object
#  6   ZipCode        447 non-null    object
#  7   Country        447 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 31.4+ KB

# %%
# Lets find how how many nulls are in each column
df_unique_hospitals.isna().sum()
# Out:
# Type             0
# CCN              0
# ID               0
# Hospital_Name    0
# City             0
# State            0
# ZipCode          0
# Country          0
# dtype: int64

# %%
# delete all rows with column 'NPI' being Null
df_unique_hospitals = df_unique_hospitals.dropna(subset=['CCN'])
df_unique_hospitals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 1757 to 5822337
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           447 non-null    object
#  1   CCN            447 non-null    float64
#  2   ID             447 non-null    float64
#  3   Hospital_Name  447 non-null    object
#  4   City           447 non-null    object
#  5   State          447 non-null    object
#  6   ZipCode        447 non-null    object
#  7   Country        447 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 31.4+ KB

# %%
# Lets find how how many nulls are left in each column
df_unique_hospitals.isna().sum()
# Out:
# Type             0
# CCN              0
# ID               0
# Hospital_Name    0
# City             0
# State            0
# ZipCode          0
# Country          0
# dtype: int64

# %%
# ID and CCN columns are the only numeric data types, lets take a look
df_unique_hospitals[['ID', 'CCN']].head
# Out:
# <bound method NDFrame.head of              ID       CCN
# 1757     9287.0  430016.0
# 1758     9736.0  360055.0
# 1760     9226.0  240063.0
# 1761     9371.0  493301.0
# 2517     9426.0  110006.0
# ...         ...       ...
# 5795520  8963.0  220111.0
# 5811813  8696.0  330181.0
# 5811818  8965.0  233027.0
# 5811826  9114.0  143027.0
# 5822337  9800.0  464009.0
#
# [447 rows x 2 columns]>

# %%
# It looks like they are composed of integer values represented as decimals. Lets convert these columns to ints.
df_unique_hospitals[['ID', 'CCN']]=df_unique_hospitals[['ID', 'CCN']].astype(int)
df_unique_hospitals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 1757 to 5822337
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           447 non-null    object
#  1   CCN            447 non-null    int64
#  2   ID             447 non-null    int64
#  3   Hospital_Name  447 non-null    object
#  4   City           447 non-null    object
#  5   State          447 non-null    object
#  6   ZipCode        447 non-null    object
#  7   Country        447 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %%
df_unique_hospitals[['ID', 'CCN']].head(10)
# Out:
#          ID     CCN
# 1757   9287  430016
# 1758   9736  360055
# 1760   9226  240063
# 1761   9371  493301
# 2517   9426  110006
# 2522   9442  110087
# 2525   9032  360020
# 7706   9713  454076
# 8899   9083  140010
# 10234  9672  453302

# %%
#Now lets reset the index of the df_unique_hospitals data frame to  the NPI column
df_unique_hospitals.set_index('CCN', inplace=True)
df_unique_hospitals.head()
# Out:
#                                        Type    ID  \
# CCN
# 430016  Covered Recipient Teaching Hospital  9287
# 360055  Covered Recipient Teaching Hospital  9736
# 240063  Covered Recipient Teaching Hospital  9226
# 493301  Covered Recipient Teaching Hospital  9371
# 110006  Covered Recipient Teaching Hospital  9426
#
#                              Hospital_Name         City State ZipCode  \
# CCN
# 430016                      Avera McKennan  Sioux Falls    SD   57117
# 360055          Trumbull Memorial Hospital       Warran    OH   44483
# 240063      Healtheast St Josephs Hospital    Rochester    MN   55102
# 493301  Childrens Hospital of the Kings Da      Norfolk    VA   23507
# 110006     ST MARYS HEALTH CARE SYSTEM INC       ATHENS    GA   30606
#
#               Country
# CCN
# 430016  United States
# 360055  United States
# 240063  United States
# 493301  United States
# 110006  United States

# %%
# I notices the Hospital_Name and City columns have mixed case. To meake it simpler, and based on the dashboard, lets make them consistent
df_unique_hospitals['Hospital_Name']=df_unique_hospitals['Hospital_Name'].str.capitalize()
df_unique_hospitals['City']=df_unique_hospitals['City'].str.capitalize()
df_unique_hospitals
# Out:
#                                        Type    ID  \
# CCN
# 430016  Covered Recipient Teaching Hospital  9287
# 360055  Covered Recipient Teaching Hospital  9736
# 240063  Covered Recipient Teaching Hospital  9226
# 493301  Covered Recipient Teaching Hospital  9371
# 110006  Covered Recipient Teaching Hospital  9426
# ...                                     ...   ...
# 220111  Covered Recipient Teaching Hospital  8963
# 330181  Covered Recipient Teaching Hospital  8696
# 233027  Covered Recipient Teaching Hospital  8965
# 143027  Covered Recipient Teaching Hospital  9114
# 464009  Covered Recipient Teaching Hospital  9800
#
#                                Hospital_Name            City State ZipCode  \
# CCN
# 430016                        Avera mckennan     Sioux falls    SD   57117
# 360055            Trumbull memorial hospital          Warran    OH   44483
# 240063        Healtheast st josephs hospital       Rochester    MN   55102
# 493301    Childrens hospital of the kings da         Norfolk    VA   23507
# 110006       St marys health care system inc          Athens    GA   30606
# ...                                      ...             ...   ...     ...
# 220111         Good samaritan medical center        Brockton    MA   02301
# 330181                    Glen cove hospital       Glen cove    NY   11542
# 233027  Rehabilitation institute of michigan         Detroit    MI   48201
# 143027     Marianjoy rehab hospital & clinic         Wheaton    IL   60187
# 464009  U of utah neuropsychiatric institute  Salt lake city    UT   84108
#
#               Country
# CCN
# 430016  United States
# 360055  United States
# 240063  United States
# 493301  United States
# 110006  United States
# ...               ...
# 220111  United States
# 330181  United States
# 233027  United States
# 143027  United States
# 464009  United States
#
# [447 rows x 7 columns]

# %%
df_unique_hospitals.to_csv('/content/gdrive/My Drive/Team3Folder/Data/Processed/OP_2020_hospitals.csv', encoding='utf-8')
